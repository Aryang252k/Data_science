# %%
import pandas as pd
import requests
from IPython.display import clear_output

# %%
response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=5179b140ede94887265ed17413072e8d&language=en-US&page=500")

# %%
response
# Out:
# <Response [200]>

# %%
df1=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
df1
# Out:
#         id                          title  \
# 0    86834                           Noah
# 1    11547                    Cabin Fever
# 2     5552                       Immortal
# 3   336011                     White Girl
# 4   254302                      High-Rise
# 5   370567                Sherlock Gnomes
# 6   329815                       Disorder
# 7   116613                    The Sweeney
# 8    16337  The Texas Chainsaw Massacre 2
# 9     2210           Earth Girls Are Easy
# 10  139567                 Fire with Fire
# 11   24271               The Maiden Heist
# 12   18298                The Three Kings
# 13  231474                    The Hunters
# 14   12620                The House Bunny
# 15  373314                     Misconduct
# 16    2047                 The Real McCoy
# 17  624808            Love Wedding Repeat
# 18  345914                      The House
# 19  114606            Cockneys vs Zombies
#
# ...

# %%
#dfd=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
dfd
concat_df=pd.concat([df1,dfd],ignore_index=True)
concat_df
# Out:
#         id                                          title  \
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4    19404                    Dilwale Dulhania Le Jayenge
# 5      129                                  Spirited Away
# 6      389                                   12 Angry Men
# 7   372058                                     Your Name.
# 8   496243                                       Parasite
# 9      155                                The Dark Knight
# 10     497                                 The Green Mile
# 11     680                                   Pulp Fiction
# 12      13                                   Forrest Gump
# 13     122  The Lord of the Rings: The Return of the King
# 14  569094            Spider-Man: Across the Spider-Verse
# ...

# %%
df=pd.DataFrame()
for i in range(1,569):
    try:
        response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=5179b140ede94887265ed17413072e8d&language=en-US&page={}".format(i))
        temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    except KeyError as k:
        print("Completed!")
        break
  # df=df.append(temp_df,ignore_index=True)  use pd.concat to avoid warning
    df=pd.concat([df,temp_df],ignore_index=True)
    clear_output(wait=True)
    print(f"Completed: {i}%")
# Out:
# Completed: 37%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 for i in range(1,569):
#       3     try:
# ----> 4         response=requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=5179b140ede94887265ed17413072e8d&language=en-US&page={}".format(i))
#       5         temp_df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#       6     except KeyError as k:
#
# File /usr/lib/python3/dist-packages/requests/api.py:76, in get(url, params, **kwargs)
#      65 r"""Sends a GET request.
#      66
#      67 :param url: URL for the new :class:`Request` object.
#    (...)
#      72 :rtype: requests.Response
#      73 """
#      75 kwargs.setdefault('allow_redirects', True)
# ---> 76 return request('get', url, params=params, **kwargs)
#
# ...

# %%
#df.iloc[9970:10020]
df.to_csv("fmovies.csv")

# %%
df
# Out:
#          id                           title  \
# 0       238                   The Godfather
# 1       278        The Shawshank Redemption
# 2       240           The Godfather Part II
# 3       424                Schindler's List
# 4     19404     Dilwale Dulhania Le Jayenge
# ..      ...                             ...
# 735    2108              The Breakfast Club
# 736  492188                  Marriage Story
# 737   49046  All Quiet on the Western Front
# 738     925              Do the Right Thing
# 739  435366                 Fabricated City
#
#                                               overview release_date  \
# 0    Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1    Framed in the 1940s for the double murder of h...   1994-09-23
# 2    In the continuing saga of the Corleone crime f...   1974-12-20
# 3    The true story of how businessman Oskar Schind...   1993-12-15
# 4    Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...
