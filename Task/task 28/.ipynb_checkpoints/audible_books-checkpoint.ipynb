# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel('/home/aryan/Downloads/audible_uncleaned.xlsx')
df
# Out:
#                                              name                     author  \
# 0                      Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                                The Burning Maze      Writtenby:RickRiordan
# 2                                    The Deep End       Writtenby:JeffKinney
# 3                            Daughter of the Deep      Writtenby:RickRiordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# ...                                           ...                        ...
# 87484                   Last Days of the Bus Club     Writtenby:ChrisStewart
# 87485                                    The Alps    Writtenby:StephenO'Shea
# 87486                        The Innocents Abroad        Writtenby:MarkTwain
# 87487                       A Sentimental Journey   Writtenby:LaurenceSterne
# 87488                                      Havana    Writtenby:MarkKurlansky
#
# ...

# %%
df.sample(50)
# Out:
#                                                     name  \
# 334                                 The 39 Clues, Book 9
# 16001  ç¬¬255å›ž æ–°åˆŠãƒ©ã‚¸ã‚ªç¬¬2éƒ¨ãƒ—ãƒ¬ãƒŸã‚¢ãƒ...
# 83635                                 Try Not to Breathe
# 36585  Manipulation and Dark Psychology: How to Manip...
# 79993                             ÐœÐ°Ð³Ð¸Ð½Ñ [Maginya]
# 34792                      Sprich nach und werde schlank
# 36395                                Transcending Trauma
# 74651                                 The Embattled Road
# 80767                      Basketball (and Other Things)
# 85984                           Are We Nearly There Yet?
# 64755                             Pastels and Pedophiles
# 83967                                       ÐšÐ¾Ñ€Ñ‚Ð¸Ðº
# 81288                                       Arnie & Jack
# 85662                        The Legend of Sleepy Hollow
# 54402                                The Fashion Orphans
# ...

# %% [markdown]
# # Data accessing

# %% [markdown]
# # Summary of data
#    This is a dataset which contian's information of audible book's (i.e data of book's which are published in audio form) . This dataset tell about author,narrator,price of audible book,language,time and also release date of audible book.

# %% [markdown]
# # Description of column's

# %% [markdown]
# **`name`** -> This column contain's the name of audible book's.<br>
# **`author`**-> This column contain's the name of author of book's.<br>
# **`narrator`**-> This column contain's the name of narrator of book's.<br>
# **`time`** -> This column contain's the duration of audible book's.<br>
# **`releasedata`** -> This column contian's the release date of audible book's.<br>
# **`language`** -> This column contian's the language of the audible book'k.<br>
# **`star`** -> This column contian's the rating in the form star (i.e out of five star).<br>
# **`price`** -> This column contain the price of audible book's.

# %% [markdown]
# # Issues with dataset
# **Quality Issues or Dirty data**<br><br>
# **`name`** ->
# * japanese,russian,arabic language is not supported
# * Book version is not in uniform formate.
# * it has special character's like (#11 & #12, €™s,25-32,©,Ã) in row like (2,11,13,14,17,25,32) and many more.
# * row (375,378,396,398,(433 to 445))and many more has invalide value (ÐœÐ°Ð»ÐµÐ½ÑŒÐºÐ¸Ð¹ Ð»Ð¾Ñ€Ð´ Ð¤Ð°ÑƒÐ½Ñ‚Ð»ÐµÑ€Ð¾Ð¹,ÐÐµ Ð±ÑƒÐ´Ñƒ Ð¿Ñ€Ð¾ÑÐ¸Ñ‚ÑŒ Ð¿Ñ€Ð¾Ñ‰ÐµÐ½Ð¸Ñ) `validity` <br><br>
# **`author`** ->
# * Each row has unnecessary words i.e "Writtenby:".<br><br>
# **`narrator`** ->
# * Each row has unnecessary owrds i.e "Narratedby:".
# * row (375,378,389,396,398,(433 to 445)) many more has invalide values i.e (Ð›ÑŽÐ±Ð¾Ð²ÑŒÐŸÐ¾Ð²Ð¾Ð»Ð¾Ñ†ÐºÐ°Ñ,Ð•Ð»ÐµÐ½Ð°Ð”ÐµÐ»ÑŒÐ²ÐµÑ€,Ð˜Ð³Ð¾Ñ€ÑŒÐ¡ÐµÑ€Ð³ÐµÐµÐ²,ÐœÐ°ÐºÑÐ¸Ð¼Ð¡ÐµÑ€Ð³ÐµÐµÐ²) `validity`<br><br>
# **`time`** ->
# * values are in consistent i.e some time in hour and some time  in minutes and sometime in both "3 hrs and 50 mins"
#    some rows contains unecessary data "00:00:00" i.e row (20049,24501) manny more.
# * values are in object form instead of time and date form .
# * convert all valiues in minutes and remove "hrs" and "mins". `Accuracy`<br><br>
# **`releasedate`** ->
# * Some rows contains unnecessary spaces.
# * values are in object form instead of time and date form .
# * Data is sometime in "05/02/2017" and "24-09-19" in formate. `Consistency`<br><br>
# **`star`** ->
# * it should be in int form i.e (0 to 5) but it is in object form "4.5 out of 5 stars41 ratings".
# * there are several missing values i.e from (71 to 84) and many more which should be represented by 0 instead of "Not rated yet". `Accuracy`<br><br>
# **`price`** ->
# * Every row contains unnecessary spaces.
# * Some rows contains "Free" values which changes dtype of 'price' e.g (983,1414 )
# * Values data should int or float.
# <br><br>
# **Structural Issues or Messy data**<br><br>
# **`star`** ->
# * It contains information total rating as well as average rating like "4.5 out of 5 stars41 ratings".
# * Two seperate column can be created for average and total rating.

# %%
df.head(50)
# Out:
#                                                  name  \
# 0                          Geronimo Stilton #11 & #12
# 1                                    The Burning Maze
# 2                                        The Deep End
# 3                                Daughter of the Deep
# 4          The Lightning Thief: Percy Jackson, Book 1
# 5                   The Hunger Games: Special Edition
# 6                         Quest for the Diamond Sword
# 7                                   The Dark Prophecy
# 8                           Merlin Mission Collection
# 9                                 The Tyrantâ€™s Tomb
# 10           The Titan's Curse: Percy Jackson, Book 3
# 11            Magic Tree House Collection: Books 9-16
# 12             Magic Tree House Collection: Books 1-8
# 13              Magnus Chase and the Ship of the Dead
# 14                                    Northern Lights
# 15                       Geronimo Stilton #13 and #14
# ...

# %%
df.tail(50)
# Out:
#                                                  name  \
# 87439                     Andrew Zimmern Visits Japan
# 87440                               A Castle in Spain
# 87441                                        Holidays
# 87442                              From Here to There
# 87443           Travels with a Donkey in the Cevennes
# 87444                                  A to Z of Hell
# 87445                               Grand Canyon Tour
# 87446                             Letters from Hawaii
# 87447                             Gates of the Arctic
# 87448                            Loving Them to Death
# 87449                                 Descent to Mars
# 87450                        Living Under the Volcano
# 87451                              Embrace the Misery
# 87452                             French Word Booster
# 87453            Dave Gorman Vs The Rest of the World
# 87454             Dave Gorman's Googlewhack Adventure
# ...

# %%
df.sample(50)
# Out:
#                                                     name  \
# 43390                                            Fairest
# 12349                            The Tale of Solomon Owl
# 54761                         Een wonderlijke winterreis
# 72644                                   Vision in Silver
# 35314                     Mad Dogs and Other New Yorkers
# 24204                              A Place Called Ananda
# 85134                         The Map from Here to There
# 24725                                   The Four Teresas
# 11716                             Poets of the Great War
# 4646                          Wer war die GlÃ¼cklichste?
# 44411                                          Witchmark
# 388    James und die fischige Fracht / Hiro und die w...
# 32979                             S'Ã©veiller en rÃªvant
# 17464  ã‚¨ãƒ³ã‚¿ãƒ¼ãƒ†ã‚¤ãƒ³ãƒ¡ãƒ³ãƒˆã®ãƒ«ãƒ¼ãƒ„/ãƒ­...
# 35198                                           Code Red
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  object
#  1   author       87489 non-null  object
#  2   narrator     87489 non-null  object
#  3   time         87489 non-null  object
#  4   releasedate  87489 non-null  object
#  5   language     87489 non-null  object
#  6   stars        87489 non-null  object
#  7   price        87489 non-null  object
# dtypes: object(8)
# memory usage: 5.3+ MB

# %%
df.isnull()
# Out:
#         name  author  narrator   time  releasedate  language  stars  price
# 0      False   False     False  False        False     False  False  False
# 1      False   False     False  False        False     False  False  False
# 2      False   False     False  False        False     False  False  False
# 3      False   False     False  False        False     False  False  False
# 4      False   False     False  False        False     False  False  False
# ...      ...     ...       ...    ...          ...       ...    ...    ...
# 87484  False   False     False  False        False     False  False  False
# 87485  False   False     False  False        False     False  False  False
# 87486  False   False     False  False        False     False  False  False
# 87487  False   False     False  False        False     False  False  False
# 87488  False   False     False  False        False     False  False  False
#
# [87489 rows x 8 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated(['author','narrator'])]
# Out:
#                                            name  \
# 7                             The Dark Prophecy
# 9                           The Tyrantâ€™s Tomb
# 10     The Titan's Curse: Percy Jackson, Book 3
# 11      Magic Tree House Collection: Books 9-16
# 12       Magic Tree House Collection: Books 1-8
# ...                                         ...
# 87473                                 Vicksburg
# 87476                      Uganda Be Kidding Me
# 87479                          Dear Bob and Sue
# 87480                       Journey into Cyprus
# 87481                       The Hills of Adonis
#
#                                author                               narrator  \
# 7               Writtenby:RickRiordan               Narratedby:RobbieDaymond
# 9               Writtenby:RickRiordan               Narratedby:RobbieDaymond
# 10              Writtenby:RickRiordan              Narratedby:JesseBernstein
# ...

# %%
df[df.duplicated(subset=['name'])]
# Out:
#                                              name  \
# 18                      Merlin Mission Collection
# 46     The Lightning Thief: Percy Jackson, Book 1
# 54                      Merlin Mission Collection
# 155                        Barbie - Superprincesa
# 273                           Barbie - Dreamtopia
# ...                                           ...
# 87443       Travels with a Donkey in the Cevennes
# 87456                                  Gettysburg
# 87457                                        Solo
# 87475                                  Wanderlust
# 87486                        The Innocents Abroad
#
#                                            author  \
# 18                      Writtenby:MaryPopeOsborne
# 46                          Writtenby:RickRiordan
# 54                      Writtenby:MaryPopeOsborne
# 155                              Writtenby:Mattel
# 273    Writtenby:Mattel,MartaCisaMuÃ±oz-traductor
# ...                                           ...
# ...

# %%
df.describe() # can'nt be done all data are oblect typ
# Out:
#                   name                            author  \
# count            87489                             87489
# unique           82767                             48374
# top     The Art of War  Writtenby:çŸ¢å³¶é›…å¼˜,çŸ³æ©‹éŠ
# freq                20                               874
#
#                     narrator    time releasedate language          stars  \
# count                  87489   87489       87489    87489          87489
# unique                 29717    2284        5059       36            665
# top     Narratedby:anonymous  2 mins    16-05-18  English  Not rated yet
# freq                    1034     372         773    61884          72417
#
#         price
# count   87489
# unique   1011
# top       586
# freq     5533

# %%
df.shape
# Out:
# (87489, 8)

# %%
df['price'].sample(50)
# Out:
# 77609     837
# 56138     234
# 22339     691
# 37726     879
# 77257    1340
# 23266     502
# 71450     773
# 44169     891
# 53075     134
# 72854    1003
# 36522    1181
# 4417       82
# 83464    1382
# 20639     233
# 24577     670
# 7865       93
# 78255     668
# 42048     668
# 31181     414
# 44534     323
# 6227       46
# 66192     914
# 76118    1172
# 61458     586
# 57915     668
# 53279     793
# 48080     166
# 4917      501
# 2321      234
# 62483     421
# 35293     469
# 11596     668
# 58482     133
# 75271     234
# 80609     703
# 85885     500
# 18645     645
# 40151    1003
# 11838     586
# 73176    1133
# 70329     585
# 41151     586
# 74945     586
# 38854     333
# 5244      166
# 70050     190
# 76594     668
# 47174     733
# 54052     569
# 66372     113
# Name: price, dtype: object

# %%
df[df['language']=='japanese'].count()
# Out:
# name           3167
# author         3167
# narrator       3167
# time           3167
# releasedate    3167
# language       3167
# stars          3167
# price          3167
# dtype: int64

# %%
df[df['price']=='Free']
# Out:
#                                             name  \
# 983                             Ringo & the Yogi
# 1414                        The Velveteen Rabbit
# 1513       Billi Aur Moosarani [Cat and Musrani]
# 2932           Pariyon Ki Kahaniya [Fairy Tales]
# 4547         101 Best Indian Fables for Children
# ...                                          ...
# 80021                           FREE: The Undead
# 81198                      Supporters. Le Pilote
# 82644                         Boots Belts Berets
# 86771                          Canada Is Awesome
# 86927  Osez l'aventure avec Mike Horn. Le pilote
#
#                                      author  \
# 983                     Writtenby:PrasunRoy
# 1414              Writtenby:MargeryWilliams
# 1513                      Writtenby:Shivani
# 2932                   Writtenby:JacobGrimm
# 4547                   Writtenby:StutiGupta
# ...                                     ...
# 80021                   Writtenby:RRHaywood
# ...

# %%
df['stars']=df['stars'].replace('Not rated yet',np.nan)
df.iloc[81198]
# Out:
# name                          Supporters. Le Pilote
# author         Writtenby:PierreNiboyet,AudreyPoiret
# narrator                  Narratedby:BorisRehlinger
# time                                        24 mins
# releasedate                                29-10-20
# language                                     french
# stars                                           NaN
# price                                          Free
# Name: 81198, dtype: object

# %%
def find_total_rating(txt):
     if pd.isna(txt):
        return txt
     try:
        ar=txt.split(' ')
        return int(ar[4].split('s')[2])  
    
     except Exception as e:
        return int(ar[4].split('s')[2].replace(',','')) 

def find_average_rating(txt):
     if pd.isna(txt):
        return txt
     try:
        ar=txt.split(' ')
        return float(ar[0])  
    
     except Exception as e:
        print(e)

# %%
df['total_rating']=df['stars'].apply(lambda x:find_total_rating(x))
df['average_rating']=df['stars'].apply(lambda x:find_average_rating(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            87489 non-null  object
#  1   author          87489 non-null  object
#  2   narrator        87489 non-null  object
#  3   time            87489 non-null  object
#  4   releasedate     87489 non-null  object
#  5   language        87489 non-null  object
#  6   stars           15072 non-null  object
#  7   price           87489 non-null  object
#  8   total_rating    15072 non-null  float64
#  9   average_rating  15072 non-null  float64
# dtypes: float64(2), object(8)
# memory usage: 6.7+ MB

# %%
df.replace(np.nan,0,inplace=True)
df['total_rating']=df['total_rating'].astype('int32')

# %%
df.drop(column)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            87489 non-null  object
#  1   author          87489 non-null  object
#  2   narrator        87489 non-null  object
#  3   time            87489 non-null  object
#  4   releasedate     87489 non-null  object
#  5   language        87489 non-null  object
#  6   stars           87489 non-null  object
#  7   price           87489 non-null  object
#  8   total_rating    87489 non-null  int32
#  9   average_rating  87489 non-null  float64
# dtypes: float64(1), int32(1), object(8)
# memory usage: 6.3+ MB
